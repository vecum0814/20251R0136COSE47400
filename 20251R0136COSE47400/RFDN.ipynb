# %%
# !pip install torch torchvision numpy scikit-image imageio matplotlib tqdm opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in ./.local/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: torchvision in ./.local/lib/python3.10/site-packages (0.15.2)
# Requirement already satisfied: numpy in ./.local/lib/python3.10/site-packages (1.24.3)
# Requirement already satisfied: scikit-image in ./.local/lib/python3.10/site-packages (0.25.2)
# Requirement already satisfied: imageio in ./.local/lib/python3.10/site-packages (2.37.0)
# Requirement already satisfied: matplotlib in ./.local/lib/python3.10/site-packages (3.10.1)
# Requirement already satisfied: tqdm in ./.local/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: opencv-python in ./.local/lib/python3.10/site-packages (4.11.0.86)
# Requirement already satisfied: filelock in ./.local/lib/python3.10/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions in ./.local/lib/python3.10/site-packages (from torch) (4.13.2)
# Requirement already satisfied: sympy in ./.local/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in ./.local/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in ./.local/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in ./.local/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in ./.local/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in ./.local/lib/python3.10/site-packages (from torch) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in ./.local/lib/python3.10/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in ./.local/lib/python3.10/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in ./.local/lib/python3.10/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in ./.local/lib/python3.10/site-packages (from torch) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in ./.local/lib/python3.10/site-packages (from torch) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in ./.local/lib/python3.10/site-packages (from torch) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in ./.local/lib/python3.10/site-packages (from torch) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in ./.local/lib/python3.10/site-packages (from torch) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in ./.local/lib/python3.10/site-packages (from torch) (2.0.0)
# Requirement already satisfied: setuptools in ./.local/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (80.3.1)
# Requirement already satisfied: wheel in ./.local/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.45.1)
# Requirement already satisfied: cmake in ./.local/lib/python3.10/site-packages (from triton==2.0.0->torch) (4.0.2)
# Requirement already satisfied: lit in ./.local/lib/python3.10/site-packages (from triton==2.0.0->torch) (18.1.8)
# Requirement already satisfied: requests in ./.local/lib/python3.10/site-packages (from torchvision) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.local/lib/python3.10/site-packages (from torchvision) (11.2.1)
# Requirement already satisfied: scipy>=1.11.4 in ./.local/lib/python3.10/site-packages (from scikit-image) (1.15.2)
# Requirement already satisfied: tifffile>=2022.8.12 in ./.local/lib/python3.10/site-packages (from scikit-image) (2025.3.30)
# Requirement already satisfied: packaging>=21 in ./.local/lib/python3.10/site-packages (from scikit-image) (23.2)
# Requirement already satisfied: lazy-loader>=0.4 in ./.local/lib/python3.10/site-packages (from scikit-image) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in ./.local/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.local/lib/python3.10/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.local/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.local/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.local/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.10/site-packages (from requests->torchvision) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.local/lib/python3.10/site-packages (from requests->torchvision) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.local/lib/python3.10/site-packages (from requests->torchvision) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.local/lib/python3.10/site-packages (from requests->torchvision) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.local/lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %%
# !ls
# Out:
# BasicSR		    Low_test.jpeg	       Real-ESRGAN
# DIV2K_train_HR.zip  Low_test_samesize.jpeg     Real-ESRGAN_Dataset.ipynb
# DIV2K_valid_HR.zip  Normal.jpeg		       Real-ESRGAN.ipynb
# DnCNN		    Normal_test.jpeg	       Untitled1.ipynb
# dncnn_baseline.pth  Normal_test_samesize.jpeg  Untitled.ipynb
# Low.jpeg	    Original.jpeg	       weights
# Low_test2.jpeg	    output_compressed

# %%
# !git clone https://github.com/thstkdgus35/EDSR-PyTorch.git
# Out:
# Cloning into 'EDSR-PyTorch'...
# remote: Enumerating objects: 806, done.
# remote: Total 806 (delta 0), reused 0 (delta 0), pack-reused 806 (from 1)
# Receiving objects: 100% (806/806), 63.09 MiB | 18.80 MiB/s, done.
# Resolving deltas: 100% (516/516), done.

# %%
# %cd EDSR-PyTorch
# Out:
# /home/elicer/EDSR-PyTorch
# /home/elicer/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !ls
# Out:
# experiment  figs  LICENSE  README.md  src  test

# %%
# !git clone https://github.com/njulj/RFDN.git RFDN_repo
# Out:
# Cloning into 'RFDN_repo'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 48 (delta 0), reused 1 (delta 0), pack-reused 44 (from 1)
# Receiving objects: 100% (48/48), 1.57 MiB | 32.07 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
# !ls
# Out:
# experiment  figs  LICENSE  README.md  RFDN_repo  src  test

# %%
# !cp RFDN_repo/RFDN.py ./src/model/
# !cp RFDN_repo/block.py ./src/model/

# %%
# !pip install torch torchvision
# !pip install numpy Pillow opencv-python scikit-image tqdm matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /home/elicer/.local/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: torchvision in /home/elicer/.local/lib/python3.10/site-packages (0.15.2)
# Requirement already satisfied: filelock in /home/elicer/.local/lib/python3.10/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions in /home/elicer/.local/lib/python3.10/site-packages (from torch) (4.13.2)
# Requirement already satisfied: sympy in /home/elicer/.local/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /home/elicer/.local/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/elicer/.local/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/elicer/.local/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/elicer/.local/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/elicer/.local/lib/python3.10/site-packages (from torch) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/elicer/.local/lib/python3.10/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/elicer/.local/lib/python3.10/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/elicer/.local/lib/python3.10/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/elicer/.local/lib/python3.10/site-packages (from torch) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/elicer/.local/lib/python3.10/site-packages (from torch) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/elicer/.local/lib/python3.10/site-packages (from torch) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/elicer/.local/lib/python3.10/site-packages (from torch) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/elicer/.local/lib/python3.10/site-packages (from torch) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/elicer/.local/lib/python3.10/site-packages (from torch) (2.0.0)
# Requirement already satisfied: setuptools in /home/elicer/.local/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (80.3.1)
# Requirement already satisfied: wheel in /home/elicer/.local/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.45.1)
# Requirement already satisfied: cmake in /home/elicer/.local/lib/python3.10/site-packages (from triton==2.0.0->torch) (4.0.2)
# Requirement already satisfied: lit in /home/elicer/.local/lib/python3.10/site-packages (from triton==2.0.0->torch) (18.1.8)
# Requirement already satisfied: numpy in /home/elicer/.local/lib/python3.10/site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: requests in /home/elicer/.local/lib/python3.10/site-packages (from torchvision) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/elicer/.local/lib/python3.10/site-packages (from torchvision) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/elicer/.local/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/elicer/.local/lib/python3.10/site-packages (from requests->torchvision) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/elicer/.local/lib/python3.10/site-packages (from requests->torchvision) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/elicer/.local/lib/python3.10/site-packages (from requests->torchvision) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/elicer/.local/lib/python3.10/site-packages (from requests->torchvision) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/elicer/.local/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/elicer/.local/lib/python3.10/site-packages (1.24.3)
# Requirement already satisfied: Pillow in /home/elicer/.local/lib/python3.10/site-packages (11.2.1)
# Requirement already satisfied: opencv-python in /home/elicer/.local/lib/python3.10/site-packages (4.11.0.86)
# Requirement already satisfied: scikit-image in /home/elicer/.local/lib/python3.10/site-packages (0.25.2)
# Requirement already satisfied: tqdm in /home/elicer/.local/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: matplotlib in /home/elicer/.local/lib/python3.10/site-packages (3.10.1)
# Requirement already satisfied: scipy>=1.11.4 in /home/elicer/.local/lib/python3.10/site-packages (from scikit-image) (1.15.2)
# Requirement already satisfied: networkx>=3.0 in /home/elicer/.local/lib/python3.10/site-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /home/elicer/.local/lib/python3.10/site-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/elicer/.local/lib/python3.10/site-packages (from scikit-image) (2025.3.30)
# Requirement already satisfied: packaging>=21 in /home/elicer/.local/lib/python3.10/site-packages (from scikit-image) (23.2)
# Requirement already satisfied: lazy-loader>=0.4 in /home/elicer/.local/lib/python3.10/site-packages (from scikit-image) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/elicer/.local/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/elicer/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/elicer/.local/lib/python3.10/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/elicer/.local/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/elicer/.local/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/elicer/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/elicer/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# %cd ..
# Out:
# /home/elicer

# %%
# !ls
# Out:
# BasicSR		    Low_test2.jpeg	       Real-ESRGAN
# content		    Low_test.jpeg	       Real-ESRGAN_Dataset.ipynb
# DIV2K_train_HR.zip  Low_test_samesize.jpeg     Real-ESRGAN.ipynb
# DIV2K_valid_HR.zip  Normal.jpeg		       Untitled1.ipynb
# DnCNN		    Normal_test.jpeg	       Untitled.ipynb
# dncnn_baseline.pth  Normal_test_samesize.jpeg  weights
# EDSR-PyTorch	    Original.jpeg
# Low.jpeg	    output_compressed

# %%
# !cp -r Real-ESRGAN/datasets/DIV2K/DIV2K_train_HR ./content/data/DIV2K/

# %%
# %cd content/data/DIV2K
# Out:
# /home/elicer/content/data/DIV2K

# %%
# !ls
# Out:
# BasicSR		    Low_test2.jpeg	       Real-ESRGAN
# content		    Low_test.jpeg	       Real-ESRGAN_Dataset.ipynb
# DIV2K_train_HR.zip  Low_test_samesize.jpeg     Real-ESRGAN.ipynb
# DIV2K_valid_HR.zip  Normal.jpeg		       Untitled1.ipynb
# DnCNN		    Normal_test.jpeg	       Untitled.ipynb
# dncnn_baseline.pth  Normal_test_samesize.jpeg  weights
# EDSR-PyTorch	    Original.jpeg
# Low.jpeg	    output_compressed

# %%
# !cp -r Real-ESRGAN/datasets/DIV2K/DIV2K_train_LQ ./content/data/DIV2K/

# %%
# !cp -r Real-ESRGAN/datasets/DIV2K/DIV2K_valid_HR ./content/data/DIV2K/

# %%
# !cp -r Real-ESRGAN/datasets/DIV2K/DIV2K_valid_LQ ./content/data/DIV2K/

# %%
# %cd EDSR-PyTorch
# Out:
# /home/elicer/EDSR-PyTorch

# %%
# !ls
# Out:
# experiment  figs  LICENSE  README.md  RFDN_repo  src  test

# %%
# %cd src
# Out:
# /home/elicer/EDSR-PyTorch/src

# %%
# !ls
# Out:
# content        demo.py	    loss     option.py	  trainer.py	  wandb
# data	       demo.sh	    main.py  __pycache__  utility.py
# dataloader.py  __init__.py  model    template.py  videotester.py

# %%
# !python main.py \
    --model RFDN \
    --data_train DIV2KCustom \
    --data_test DIV2KCustom \
    --dir_data content/data \
    --scale 4 \
    --patch_size 96 \
    --batch_size 16 \
    --epochs 10 \
    --lr 1e-4 \
    --save RFDN_x4_custom \
    --reset
# Out:
# Traceback (most recent call last):
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 5, in <module>
#     import model
#   File "/home/elicer/EDSR-PyTorch/src/model/__init__.py", line 3, in <module>
#     from .RFDN import RFDN
#   File "/home/elicer/EDSR-PyTorch/src/model/RFDN.py", line 3, in <module>
#     import block as B
# ModuleNotFoundError: No module named 'block'

# %%
# !python main.py \
    --model RFDN \
    --data_train DIV2KCustom \
    --data_test DIV2KCustom \
    --dir_data content/data \
    --scale 4 \
    --patch_size 96 \
    --batch_size 16 \
    --epochs 10 \
    --lr 1e-4 \
    --save RFDN_x4_custom \
    --reset
# Out:
# Traceback (most recent call last):
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 33, in <module>
#     main()
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 22, in main
#     loader = data.Data(args)
#   File "/home/elicer/EDSR-PyTorch/src/data/__init__.py", line 28, in __init__
#     datasets.append(getattr(m, class_name)(args, name=d))
#   File "/home/elicer/EDSR-PyTorch/src/data/div2k_custom.py", line 29, in __init__
#     super(DIV2KCustom, self).__init__(
#   File "/home/elicer/EDSR-PyTorch/src/data/srdata.py", line 30, in __init__
#     list_hr, list_lr = self._scan()
#   File "/home/elicer/EDSR-PyTorch/src/data/div2k_custom.py", line 62, in _scan
#     for filename in sorted(os.listdir(self.dir_hr)):
# FileNotFoundError: [Errno 2] No such file or directory: 'content/data/DIV2KCustom/DIV2K_train_HR'

# %%
# !python main.py \
    --model RFDN \
    --data_train DIV2KCustom \
    --data_test DIV2KCustom \
    --dir_data content/data \
    --scale 4 \
    --patch_size 96 \
    --batch_size 16 \
    --epochs 10 \
    --lr 1e-4 \
    --save RFDN_x4_custom \
    --reset
# Out:
# Traceback (most recent call last):
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 33, in <module>
#     main()
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 22, in main
#     loader = data.Data(args)
#   File "/home/elicer/EDSR-PyTorch/src/data/__init__.py", line 28, in __init__
#     datasets.append(getattr(m, class_name)(args, name=d))
#   File "/home/elicer/EDSR-PyTorch/src/data/div2k_custom.py", line 29, in __init__
#     super(DIV2KCustom, self).__init__(
#   File "/home/elicer/EDSR-PyTorch/src/data/srdata.py", line 30, in __init__
#     list_hr, list_lr = self._scan()
#   File "/home/elicer/EDSR-PyTorch/src/data/div2k_custom.py", line 77, in _scan
#     for filename in sorted(os.listdir(self.dir_hr)):
# FileNotFoundError: [Errno 2] No such file or directory: 'content/data/DIV2K/DIV2K_train_HR'

# %%
# !python main.py \
  --model RFDN \
  --data_train DIV2KCustom \
  --data_test DIV2KCustom \
  --dir_data /content/data \
  --scale 4 \
  --patch_size 96 \
  --batch_size 16 \
  --epochs 10 \
  --lr 1e-4 \
  --save RFDN_x4_custom \
  --reset
# Out:
# Traceback (most recent call last):
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 33, in <module>
#     main()
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 22, in main
#     loader = data.Data(args)
#   File "/home/elicer/EDSR-PyTorch/src/data/__init__.py", line 26, in __init__
#     datasets.append(DIV2KCustom(args, name=d))
#   File "/home/elicer/EDSR-PyTorch/src/data/div2k_custom.py", line 25, in __init__
#     super(DIV2KCustom, self).__init__(args, name=name, train=train, benchmark=benchmark)
#   File "/home/elicer/EDSR-PyTorch/src/data/srdata.py", line 28, in __init__
#     os.makedirs(path_bin, exist_ok=True)
#   File "/usr/local/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# PermissionError: [Errno 13] Permission denied: '/content/data/DIV2K/bin'

# %%
# !python main.py \
    --model RFDN \
    --data_train DIV2KCustom \
    --data_test DIV2KCustom \
    --dir_data /content/data \
    --scale 4 \
    --patch_size 96 \
    --batch_size 16 \
    --epochs 10 \
    --lr 1e-4 \
    --save RFDN_x4_custom \
    --ext sep \
    --reset
# Out:
# Traceback (most recent call last):
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 33, in <module>
#     main()
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 22, in main
#     loader = data.Data(args)
#   File "/home/elicer/EDSR-PyTorch/src/data/__init__.py", line 26, in __init__
#     datasets.append(DIV2KCustom(args, name=d))
#   File "/home/elicer/EDSR-PyTorch/src/data/div2k_custom.py", line 25, in __init__
#     super(DIV2KCustom, self).__init__(args, name=name, train=train, benchmark=benchmark)
#   File "/home/elicer/EDSR-PyTorch/src/data/srdata.py", line 28, in __init__
#     os.makedirs(path_bin, exist_ok=True)
#   File "/usr/local/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# PermissionError: [Errno 13] Permission denied: '/content/data/DIV2K/bin'

# %%
# !python main.py \
    --model RFDN \
    --data_train DIV2KCustom \
    --data_test DIV2KCustom \
    --dir_data /content/data \
    --scale 4 \
    --patch_size 96 \
    --batch_size 16 \
    --epochs 10 \
    --lr 1e-4 \
    --save RFDN_x4_custom \
    --reset \
    --ext img
# Out:
# Traceback (most recent call last):
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 33, in <module>
#     main()
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 22, in main
#     loader = data.Data(args)
#   File "/home/elicer/EDSR-PyTorch/src/data/__init__.py", line 26, in __init__
#     datasets.append(DIV2KCustom(args, name=d))
#   File "/home/elicer/EDSR-PyTorch/src/data/div2k_custom.py", line 25, in __init__
#     super(DIV2KCustom, self).__init__(args, name=name, train=train, benchmark=benchmark)
#   File "/home/elicer/EDSR-PyTorch/src/data/srdata.py", line 30, in __init__
#     list_hr, list_lr = self._scan()
#   File "/home/elicer/EDSR-PyTorch/src/data/div2k_custom.py", line 44, in _scan
#     for filename in sorted(os.listdir(self.dir_hr)):
# FileNotFoundError: [Errno 2] No such file or directory: '/content/data/DIV2K/DIV2K_train_HR'

# %%
# %cd ..
# Out:
# /home/elicer/EDSR-PyTorch

# %%
# %cd ..
# Out:
# /home/elicer

# %%
# %cd content/data/DIV2K/
# Out:
# /home/elicer/content/data/DIV2K
# /home/elicer/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !ls
# Out:
# DIV2K_train_HR	DIV2K_train_LQ	DIV2K_valid_HR	DIV2K_valid_LQ

# %%
# %cd ..
# Out:
# /home/elicer/content/data

# %%
# %cd ..
# Out:
# /home/elicer/content

# %%
# %cd ..
# Out:
# /home/elicer

# %%
# !ls
# Out:
# content        demo.sh	    main.py    __pycache__  utility.py
# data	       __init__.py  model      template.py  videotester.py
# dataloader.py  loss	    option.py  trainer.py

# %%
# !python main.py \
    --model RFDN \
    --data_train DIV2KCustom \
    --data_test DIV2KCustom \
    --dir_data /home/elicer/content/data \
    --scale 4 \
    --patch_size 96 \
    --batch_size 16 \
    --epochs 10 \
    --lr 1e-4 \
    --save RFDN_x4_custom \
    --reset
# Out:
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0001.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0002.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0003.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0004.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0005.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0006.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0007.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0008.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0009.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0010.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0011.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0012.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0013.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0014.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0015.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0016.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0017.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0018.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0019.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0020.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0021.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0022.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0023.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0024.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0025.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0026.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0027.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0028.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0029.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0030.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0031.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0032.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0033.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0034.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0035.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0036.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0037.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0038.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0039.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0040.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0041.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0042.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0043.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0044.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0045.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0046.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0047.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0048.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0049.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0050.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0051.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0052.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0053.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0054.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0055.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0056.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0057.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0058.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0059.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0060.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0061.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0062.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0063.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0064.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0065.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0066.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0067.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0068.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0069.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0070.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0071.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0072.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0073.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0074.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0075.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0076.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0077.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0078.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0079.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0080.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0081.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0082.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0083.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0084.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0085.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0086.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0087.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0088.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0089.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0090.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0091.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0092.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0093.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0094.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0095.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0096.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0097.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0098.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0099.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0100.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0101.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0102.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0103.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0104.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0105.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0106.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0107.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0108.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0109.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0110.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0111.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0112.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0113.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0114.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0115.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0116.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0117.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0118.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0119.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0120.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0121.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0122.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0123.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0124.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0125.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0126.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0127.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0128.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0129.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0130.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0131.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0132.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0133.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0134.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0135.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0136.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0137.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0138.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0139.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0140.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0141.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0142.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0143.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0144.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0145.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0146.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0147.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0148.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0149.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0150.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0151.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0152.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0153.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0154.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0155.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0156.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0157.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0158.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0159.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0160.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0161.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0162.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0163.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0164.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0165.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0166.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0167.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0168.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0169.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0170.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0171.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0172.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0173.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0174.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0175.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0176.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0177.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0178.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0179.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0180.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0181.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0182.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0183.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0184.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0185.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0186.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0187.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0188.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0189.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0190.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0191.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0192.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0193.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0194.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0195.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0196.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0197.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0198.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0199.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0200.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0201.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0202.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0203.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0204.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0205.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0206.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0207.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0208.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0209.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0210.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0211.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0212.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0213.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0214.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0215.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0216.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0217.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0218.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0219.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0220.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0221.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0222.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0223.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0224.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0225.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0226.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0227.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0228.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0229.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0230.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0231.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0232.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0233.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0234.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0235.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0236.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0237.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0238.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0239.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0240.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0241.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0242.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0243.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0244.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0245.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0246.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0247.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0248.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0249.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0250.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0251.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0252.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0253.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0254.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0255.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0256.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0257.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0258.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0259.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0260.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0261.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0262.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0263.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0264.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0265.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0266.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0267.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0268.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0269.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0270.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0271.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0272.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0273.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0274.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0275.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0276.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0277.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0278.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0279.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0280.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0281.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0282.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0283.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0284.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0285.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0286.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0287.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0288.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0289.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0290.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0291.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0292.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0293.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0294.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0295.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0296.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0297.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0298.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0299.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0300.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0301.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0302.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0303.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0304.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0305.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0306.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0307.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0308.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0309.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0310.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0311.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0312.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0313.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0314.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0315.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0316.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0317.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0318.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0319.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0320.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0321.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0322.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0323.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0324.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0325.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0326.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0327.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0328.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0329.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0330.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0331.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0332.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0333.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0334.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0335.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0336.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0337.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0338.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0339.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0340.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0341.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0342.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0343.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0344.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0345.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0346.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0347.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0348.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0349.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0350.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0351.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0352.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0353.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0354.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0355.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0356.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0357.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0358.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0359.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0360.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0361.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0362.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0363.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0364.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0365.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0366.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0367.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0368.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0369.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0370.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0371.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0372.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0373.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0374.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0375.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0376.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0377.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0378.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0379.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0380.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0381.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0382.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0383.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0384.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0385.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0386.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0387.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0388.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0389.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0390.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0391.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0392.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0393.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0394.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0395.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0396.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0397.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0398.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0399.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0400.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0401.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0402.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0403.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0404.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0405.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0406.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0407.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0408.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0409.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0410.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0411.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0412.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0413.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0414.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0415.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0416.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0417.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0418.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0419.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0420.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0421.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0422.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0423.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0424.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0425.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0426.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0427.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0428.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0429.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0430.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0431.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0432.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0433.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0434.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0435.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0436.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0437.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0438.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0439.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0440.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0441.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0442.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0443.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0444.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0445.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0446.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0447.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0448.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0449.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0450.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0451.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0452.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0453.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0454.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0455.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0456.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0457.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0458.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0459.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0460.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0461.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0462.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0463.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0464.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0465.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0466.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0467.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0468.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0469.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0470.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0471.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0472.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0473.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0474.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0475.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0476.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0477.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0478.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0479.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0480.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0481.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0482.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0483.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0484.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0485.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0486.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0487.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0488.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0489.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0490.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0491.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0492.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0493.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0494.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0495.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0496.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0497.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0498.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0499.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0500.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0501.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0502.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0503.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0504.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0505.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0506.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0507.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0508.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0509.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0510.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0511.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0512.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0513.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0514.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0515.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0516.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0517.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0518.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0519.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0520.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0521.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0522.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0523.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0524.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0525.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0526.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0527.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0528.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0529.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0530.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0531.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0532.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0533.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0534.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0535.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0536.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0537.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0538.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0539.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0540.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0541.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0542.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0543.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0544.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0545.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0546.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0547.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0548.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0549.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0550.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0551.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0552.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0553.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0554.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0555.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0556.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0557.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0558.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0559.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0560.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0561.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0562.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0563.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0564.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0565.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0566.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0567.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0568.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0569.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0570.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0571.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0572.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0573.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0574.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0575.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0576.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0577.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0578.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0579.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0580.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0581.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0582.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0583.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0584.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0585.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0586.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0587.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0588.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0589.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0590.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0591.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0592.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0593.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0594.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0595.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0596.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0597.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0598.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0599.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0600.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0601.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0602.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0603.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0604.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0605.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0606.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0607.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0608.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0609.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0610.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0611.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0612.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0613.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0614.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0615.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0616.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0617.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0618.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0619.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0620.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0621.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0622.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0623.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0624.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0625.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0626.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0627.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0628.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0629.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0630.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_HR/0631.pt
# ...
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0711_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0711_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0712_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0712_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0713_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0713_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0714_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0714_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0715_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0715_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0716_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0716_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0717_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0717_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0718_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0718_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0719_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0719_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0720_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0720_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0721_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0721_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0722_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0722_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0723_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0723_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0724_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0724_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0725_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0725_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0726_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0726_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0727_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0727_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0728_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0728_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0729_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0729_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0730_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0730_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0731_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0731_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0732_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0732_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0733_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0733_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0734_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0734_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0735_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0735_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0736_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0736_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0737_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0737_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0738_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0738_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0739_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0739_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0740_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0740_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0741_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0741_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0742_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0742_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0743_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0743_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0744_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0744_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0745_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0745_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0746_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0746_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0747_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0747_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0748_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0748_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0749_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0749_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0750_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0750_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0751_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0751_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0752_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0752_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0753_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0753_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0754_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0754_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0755_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0755_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0756_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0756_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0757_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0757_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0758_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0758_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0759_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0759_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0760_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0760_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0761_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0761_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0762_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0762_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0763_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0763_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0764_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0764_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0765_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0765_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0766_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0766_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0767_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0767_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0768_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0768_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0769_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0769_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0770_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0770_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0771_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0771_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0772_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0772_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0773_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0773_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0774_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0774_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0775_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0775_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0776_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0776_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0777_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0777_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0778_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0778_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0779_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0779_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0780_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0780_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0781_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0781_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0782_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0782_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0783_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0783_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0784_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0784_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0785_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0785_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0786_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0786_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0787_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0787_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0788_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0788_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0789_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0789_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0790_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0790_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0791_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0791_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0792_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0792_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0793_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0793_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0794_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0794_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0795_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0795_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0796_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0796_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0797_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0797_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0798_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0798_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0799_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0799_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0800_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_train_LQ/0800_Low.pt
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Traceback (most recent call last):
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 33, in <module>
#     main()
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 23, in main
#     _model = model.Model(args, checkpoint)
#   File "/home/elicer/EDSR-PyTorch/src/model/__init__.py", line 35, in __init__
#     module = import_module('model.' + args.model.lower())
#   File "/usr/local/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'model.rfdn'

# %%
# !python main.py \
    --model RFDN \
    --data_train DIV2KCustom \
    --data_test DIV2KCustom \
    --dir_data /home/elicer/content/data \
    --scale 4 \
    --patch_size 96 \
    --batch_size 16 \
    --epochs 10 \
    --lr 1e-4 \
    --save RFDN_x4_custom \
    --ext sep
# Out:
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Preparing loss function:
# 1.000 * L1
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 1]	Learning rate: 1.00e-4
# Traceback (most recent call last):
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 33, in <module>
#     main()
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 27, in main
#     t.train()
#   File "/home/elicer/EDSR-PyTorch/src/trainer.py", line 42, in train
#     for batch, (lr, hr, _,) in enumerate(self.loader_train):
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 633, in __next__
#     data = self._next_data()
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1345, in _next_data
#     return self._process_data(data)
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1371, in _process_data
#     data.reraise()
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/_utils.py", line 644, in reraise
#     raise exception
# AttributeError: Caught AttributeError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/_utils/worker.py", line 308, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataset.py", line 243, in __getitem__
#     return self.datasets[dataset_idx][sample_idx]
#   File "/home/elicer/EDSR-PyTorch/src/data/srdata.py", line 99, in __getitem__
#     lr, hr, filename = self._load_file(idx)
#   File "/home/elicer/EDSR-PyTorch/src/data/srdata.py", line 119, in _load_file
#     idx = self._get_index(idx)
#   File "/home/elicer/EDSR-PyTorch/src/data/div2k_custom.py", line 73, in _get_index
#     hr_size = len(self.hr)
# AttributeError: 'DIV2KCustom' object has no attribute 'hr'

# %%
# !python main.py \
    --model RFDN \
    --data_train DIV2KCustom \
    --data_test DIV2KCustom \
    --dir_data /home/elicer/content/data \
    --scale 4 \
    --patch_size 96 \
    --batch_size 16 \
    --epochs 10 \
    --lr 1e-4 \
    --save RFDN_x4_custom \
    --ext sep
# Out:
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Preparing loss function:
# 1.000 * L1
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 1]	Learning rate: 1.00e-4
# Traceback (most recent call last):
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 33, in <module>
#     main()
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 27, in main
#     t.train()
#   File "/home/elicer/EDSR-PyTorch/src/trainer.py", line 42, in train
#     for batch, (lr, hr, _,) in enumerate(self.loader_train):
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 633, in __next__
#     data = self._next_data()
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1345, in _next_data
#     return self._process_data(data)
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1371, in _process_data
#     data.reraise()
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/_utils.py", line 644, in reraise
#     raise exception
# TypeError: Caught TypeError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/_utils/worker.py", line 308, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataset.py", line 243, in __getitem__
#     return self.datasets[dataset_idx][sample_idx]
#   File "/home/elicer/EDSR-PyTorch/src/data/srdata.py", line 99, in __getitem__
#     lr, hr, filename = self._load_file(idx)
#   File "/home/elicer/EDSR-PyTorch/src/data/srdata.py", line 120, in _load_file
#     f_hr = self.images_hr[idx]
# TypeError: list indices must be integers or slices, not tuple

# %%
# !python main.py \
    --model RFDN \
    --data_train DIV2KCustom \
    --data_test DIV2KCustom \
    --dir_data /home/elicer/content/data \
    --scale 4 \
    --patch_size 96 \
    --batch_size 16 \
    --epochs 10 \
    --lr 1e-4 \
    --save RFDN_x4_custom \
    --ext sep
# Out:
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Preparing loss function:
# 1.000 * L1
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 1]	Learning rate: 1.00e-4
# Traceback (most recent call last):
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 33, in <module>
#     main()
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 27, in main
#     t.train()
#   File "/home/elicer/EDSR-PyTorch/src/trainer.py", line 42, in train
#     for batch, (lr, hr, _,) in enumerate(self.loader_train):
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 633, in __next__
#     data = self._next_data()
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1345, in _next_data
#     return self._process_data(data)
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1371, in _process_data
#     data.reraise()
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/_utils.py", line 644, in reraise
#     raise exception
# IndexError: Caught IndexError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/_utils/worker.py", line 308, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataset.py", line 243, in __getitem__
#     return self.datasets[dataset_idx][sample_idx]
#   File "/home/elicer/EDSR-PyTorch/src/data/srdata.py", line 99, in __getitem__
#     lr, hr, filename = self._load_file(idx)
#   File "/home/elicer/EDSR-PyTorch/src/data/srdata.py", line 121, in _load_file
#     f_lr = self.images_lr[self.idx_scale][lr_idx]
# IndexError: list index out of range

# %%
# !python main.py \
    --model RFDN \
    --data_train DIV2KCustom \
    --data_test DIV2KCustom \
    --dir_data /home/elicer/content/data \
    --scale 4 \
    --patch_size 96 \
    --batch_size 16 \
    --epochs 10 \
    --lr 1e-4 \
    --save RFDN_x4_custom \
    --ext sep
# Out:
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Preparing loss function:
# 1.000 * L1
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 1]	Learning rate: 1.00e-4
# [1600/1600]	[L1: 44.8251]	3.4+1.1s
#
# Evaluation:
# 100%|███████████████████████████████████████| 1600/1600 [01:19<00:00, 20.16it/s]
# [DIV2KCustom x4]	PSNR: 19.466 (Best: 19.466 @epoch 1)
# Forward: 79.43s
#
# Saving...
# Total: 80.64s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 2]	Learning rate: 1.00e-4
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [1600/1600]	[L1: 20.9581]	2.3+0.3s
#
# Evaluation:
# 100%|███████████████████████████████████████| 1600/1600 [01:18<00:00, 20.45it/s]
# [DIV2KCustom x4]	PSNR: 21.320 (Best: 21.320 @epoch 2)
# Forward: 78.24s
#
# Saving...
# Total: 78.65s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 3]	Learning rate: 1.00e-4
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [1600/1600]	[L1: 15.4833]	2.3+0.4s
#
# Evaluation:
# 100%|███████████████████████████████████████| 1600/1600 [01:18<00:00, 20.39it/s]
# [DIV2KCustom x4]	PSNR: 23.066 (Best: 23.066 @epoch 3)
# Forward: 78.46s
#
# Saving...
# Total: 78.91s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 4]	Learning rate: 1.00e-4
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [1600/1600]	[L1: 12.4335]	2.4+0.3s
#
# Evaluation:
# 100%|███████████████████████████████████████| 1600/1600 [01:18<00:00, 20.40it/s]
# [DIV2KCustom x4]	PSNR: 23.925 (Best: 23.925 @epoch 4)
# Forward: 78.41s
#
# Saving...
# Total: 78.81s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 5]	Learning rate: 1.00e-4
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [1600/1600]	[L1: 11.7465]	2.4+0.3s
#
# Evaluation:
# 100%|███████████████████████████████████████| 1600/1600 [01:18<00:00, 20.47it/s]
# [DIV2KCustom x4]	PSNR: 24.496 (Best: 24.496 @epoch 5)
# Forward: 78.15s
#
# Saving...
# Total: 78.57s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 6]	Learning rate: 1.00e-4
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [1600/1600]	[L1: 11.0006]	2.3+0.4s
#
# Evaluation:
# 100%|███████████████████████████████████████| 1600/1600 [01:18<00:00, 20.42it/s]
# [DIV2KCustom x4]	PSNR: 24.736 (Best: 24.736 @epoch 6)
# Forward: 78.37s
#
# Saving...
# Total: 78.76s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 7]	Learning rate: 1.00e-4
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [1600/1600]	[L1: 10.6015]	2.4+0.3s
#
# Evaluation:
# 100%|███████████████████████████████████████| 1600/1600 [01:18<00:00, 20.47it/s]
# [DIV2KCustom x4]	PSNR: 24.639 (Best: 24.736 @epoch 6)
# Forward: 78.17s
#
# Saving...
# Total: 78.56s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 8]	Learning rate: 1.00e-4
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [1600/1600]	[L1: 10.2279]	2.4+0.3s
#
# Evaluation:
# 100%|███████████████████████████████████████| 1600/1600 [01:18<00:00, 20.48it/s]
# [DIV2KCustom x4]	PSNR: 25.274 (Best: 25.274 @epoch 8)
# Forward: 78.13s
#
# Saving...
# Total: 78.55s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 9]	Learning rate: 1.00e-4
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [1600/1600]	[L1: 9.8531]	2.5+0.4s
#
# Evaluation:
# 100%|███████████████████████████████████████| 1600/1600 [01:18<00:00, 20.48it/s]
# [DIV2KCustom x4]	PSNR: 25.480 (Best: 25.480 @epoch 9)
# Forward: 78.11s
#
# Saving...
# Total: 78.61s

# %%
# !python main.py \
    --model RFDN \
    --data_test DIV2KCustom \
    --dir_data /home/elicer/content/data \
    --scale 4 \
    --pre_train /home/elicer/EDSR-PyTorch/experiment/RFDN_x4_custom/model/model_best.pt \
    --test_only \
    --save_results \
    --ext img
# Out:
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Load the model from /home/elicer/EDSR-PyTorch/experiment/RFDN_x4_custom/model/model_best.pt
#
# Evaluation:
# 100%|█████████████████████████████████████████| 200/200 [00:30<00:00,  6.50it/s]
# [DIV2KCustom x4]	PSNR: 25.560 (Best: 25.560 @epoch 1)
# Forward: 30.89s
#
# Saving...
# Total: 94.95s

# %%
# !python main.py \
    --model RFDN \
    --data_test Demo \
    --dir_data /home/elicer/content/single_test \
    --scale 4 \
    --pre_train ../experiment/RFDN_x4_custom/model/model_best.pt \
    --test_only \
    --save_results \
    --ext img
# Out:
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Load the model from ../experiment/RFDN_x4_custom/model/model_best.pt
#
# Evaluation:
# 100%|█████████████████████████████████████████████| 1/1 [00:04<00:00,  4.87s/it]
# [Demo x4]	PSNR: 0.000 (Best: 0.000 @epoch 1)
# Forward: 5.01s
#
# Saving...
# Total: 6.23s

# %%
# !python main.py \
    --model RFDN \
    --data_test Demo \
    --dir_data /home/elicer/content/single_test \
    --scale 4 \
    --pre_train ../experiment/RFDN_x4_custom/model/model_best.pt \
    --test_only \
    --save_results \
    --ext img
# Out:
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Load the model from ../experiment/RFDN_x4_custom/model/model_best.pt
#
# Evaluation:
# 100%|█████████████████████████████████████████████| 1/1 [00:04<00:00,  4.69s/it]
# [Demo x4]	PSNR: 0.000 (Best: 0.000 @epoch 1)
# Forward: 4.81s
#
# Saving...
# Total: 6.05s

# %%
# !python main.py \
    --model RFDN \
    --data_test Demo \
    --dir_data /home/elicer/content/single_test \
    --scale 4 \
    --pre_train ../experiment/RFDN_x4_custom/model/model_best.pt \
    --test_only \
    --save_results \
    --save RFDN_x4_custom \
    --ext img
# Out:
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Load the model from ../experiment/RFDN_x4_custom/model/model_best.pt
#
# Evaluation:
# 100%|█████████████████████████████████████████████| 1/1 [00:04<00:00,  4.81s/it]
# [Demo x4]	PSNR: 0.000 (Best: 0.000 @epoch 1)
# Forward: 4.93s
#
# Saving...
# Total: 6.15s

# %%
# !python main.py \
    --model RFDN \
    --data_test Demo \
    --dir_data /home/elicer/content/single_test \
    --scale 4 \
    --pre_train ../experiment/RFDN_x4_custom/model/model_best.pt \
    --test_only \
    --save_results \
    --save RFDN_x4_custom \
    --ext img
# Out:
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Load the model from ../experiment/RFDN_x4_custom/model/model_best.pt
#
# Evaluation:
# 100%|█████████████████████████████████████████████| 1/1 [00:04<00:00,  4.82s/it]
# [Demo x4]	PSNR: 0.000 (Best: 0.000 @epoch 1)
# Forward: 4.95s
#
# Saving...
# Total: 6.13s

# %%
# !python main.py \
    --model RFDN \
    --data_test Demo \
    --dir_data /home/elicer/content/single_test \
    --scale 4 \
    --pre_train ../experiment/RFDN_x4_custom/model/model_best.pt \
    --test_only \
    --save_results \
    --save RFDN_x4_custom \
    --ext img
# Out:
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Load the model from ../experiment/RFDN_x4_custom/model/model_best.pt
#
# Evaluation:
# 100%|█████████████████████████████████████████████| 1/1 [00:05<00:00,  5.17s/it]
# [Demo x4]	PSNR: 0.000 (Best: 0.000 @epoch 1)
# Forward: 5.30s
#
# Saving...
# Total: 12.21s

# %%
# !pip install wandb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wandb
#   Downloading wandb-0.19.11-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting click!=8.0.0,>=7.1 (from wandb)
#   Downloading click-8.2.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in ./.local/lib/python3.10/site-packages (from wandb) (4.0.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in ./.local/lib/python3.10/site-packages (from wandb) (6.30.2)
# Requirement already satisfied: psutil>=5.0.0 in ./.local/lib/python3.10/site-packages (from wandb) (5.9.6)
# Collecting pydantic<3 (from wandb)
#   Downloading pydantic-2.11.4-py3-none-any.whl.metadata (66 kB)
# Requirement already satisfied: pyyaml in ./.local/lib/python3.10/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in ./.local/lib/python3.10/site-packages (from wandb) (2.32.3)
# Collecting sentry-sdk>=2.0.0 (from wandb)
#   Downloading sentry_sdk-2.27.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.6-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in ./.local/lib/python3.10/site-packages (from wandb) (80.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.4 in ./.local/lib/python3.10/site-packages (from wandb) (4.13.2)
# Collecting annotated-types>=0.6.0 (from pydantic<3->wandb)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3->wandb)
#   Downloading pydantic_core-2.33.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3->wandb)
#   Downloading typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.local/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.local/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.local/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2025.4.26)
# Requirement already satisfied: six>=1.4.0 in ./.local/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Downloading wandb-0.19.11-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 72.4 MB/s eta 0:00:00:00:01
# Downloading pydantic-2.11.4-py3-none-any.whl (443 kB)
# Downloading pydantic_core-2.33.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 81.4 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading click-8.2.0-py3-none-any.whl (102 kB)
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading sentry_sdk-2.27.0-py2.py3-none-any.whl (340 kB)
# Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Downloading setproctitle-1.3.6-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Installing collected packages: typing-inspection, smmap, setproctitle, sentry-sdk, pydantic-core, docker-pycreds, click, annotated-types, pydantic, gitdb, gitpython, wandb
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/12 [wandb]m11/12 [wandb]hon]]
# Successfully installed annotated-types-0.7.0 click-8.2.0 docker-pycreds-0.4.0 gitdb-4.0.12 gitpython-3.1.44 pydantic-2.11.4 pydantic-core-2.33.2 sentry-sdk-2.27.0 setproctitle-1.3.6 smmap-5.0.2 typing-inspection-0.4.0 wandb-0.19.11

# %%
# !python main.py \
    --model RFDN \
    --data_train DIV2KCustom \
    --data_test DIV2KCustom \
    --dir_data /home/elicer/content/data \
    --scale 4 \
    --patch_size 96 \
    --batch_size 16 \
    --epochs 10 \
    --lr 1e-4 \
    --save RFDN_x4_custom \
    --ext sep
# Out:
# python: can't open file '/home/elicer/main.py': [Errno 2] No such file or directory

# %%
# !ls
# Out:
# BasicSR		    Low_test2.jpeg	       Real-ESRGAN
# content		    Low_test.jpeg	       Real-ESRGAN_Dataset.ipynb
# DIV2K_train_HR.zip  Low_test_samesize.jpeg     Real-ESRGAN.ipynb
# DIV2K_valid_HR.zip  Normal.jpeg		       RFDN.ipynb
# DnCNN		    Normal_test.jpeg	       Untitled.ipynb
# dncnn_baseline.pth  Normal_test_samesize.jpeg  weights
# EDSR-PyTorch	    Original.jpeg
# Low.jpeg	    output_compressed

# %%
# %cd EDSR-PyTorch/
# Out:
# /home/elicer/EDSR-PyTorch
# /home/elicer/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !ls
# Out:
# experiment  figs  LICENSE  README.md  RFDN_repo  src  test

# %%
# %cd src
# Out:
# /home/elicer/EDSR-PyTorch/src

# %%
# !ls
# Out:
# content        demo.py	    loss     option.py	  trainer.py
# data	       demo.sh	    main.py  __pycache__  utility.py
# dataloader.py  __init__.py  model    template.py  videotester.py

# %%
# !python main.py \
    --model RFDN \
    --data_train DIV2KCustom \
    --data_test DIV2KCustom \
    --dir_data /home/elicer/content/data \
    --scale 4 \
    --patch_size 96 \
    --batch_size 16 \
    --epochs 10 \
    --lr 1e-4 \
    --save RFDN_x4_custom \
    --ext sep
# Out:
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0801.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0802.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0803.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0804.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0805.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0806.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0807.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0808.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0809.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0810.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0811.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0812.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0813.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0814.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0815.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0816.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0817.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0818.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0819.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0820.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0821.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0822.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0823.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0824.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0825.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0826.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0827.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0828.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0829.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0830.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0831.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0832.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0833.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0834.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0835.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0836.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0837.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0838.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0839.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0840.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0841.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0842.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0843.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0844.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0845.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0846.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0847.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0848.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0849.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0850.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0851.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0852.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0853.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0854.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0855.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0856.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0857.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0858.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0859.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0860.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0861.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0862.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0863.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0864.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0865.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0866.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0867.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0868.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0869.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0870.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0871.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0872.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0873.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0874.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0875.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0876.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0877.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0878.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0879.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0880.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0881.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0882.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0883.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0884.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0885.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0886.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0887.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0888.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0889.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0890.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0891.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0892.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0893.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0894.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0895.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0896.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0897.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0898.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0899.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_HR/0900.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0801_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0801_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0802_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0802_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0803_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0803_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0804_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0804_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0805_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0805_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0806_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0806_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0807_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0807_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0808_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0808_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0809_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0809_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0810_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0810_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0811_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0811_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0812_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0812_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0813_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0813_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0814_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0814_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0815_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0815_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0816_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0816_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0817_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0817_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0818_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0818_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0819_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0819_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0820_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0820_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0821_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0821_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0822_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0822_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0823_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0823_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0824_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0824_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0825_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0825_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0826_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0826_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0827_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0827_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0828_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0828_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0829_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0829_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0830_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0830_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0831_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0831_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0832_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0832_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0833_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0833_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0834_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0834_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0835_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0835_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0836_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0836_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0837_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0837_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0838_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0838_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0839_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0839_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0840_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0840_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0841_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0841_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0842_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0842_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0843_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0843_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0844_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0844_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0845_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0845_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0846_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0846_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0847_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0847_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0848_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0848_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0849_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0849_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0850_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0850_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0851_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0851_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0852_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0852_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0853_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0853_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0854_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0854_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0855_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0855_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0856_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0856_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0857_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0857_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0858_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0858_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0859_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0859_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0860_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0860_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0861_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0861_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0862_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0862_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0863_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0863_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0864_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0864_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0865_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0865_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0866_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0866_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0867_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0867_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0868_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0868_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0869_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0869_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0870_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0870_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0871_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0871_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0872_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0872_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0873_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0873_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0874_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0874_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0875_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0875_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0876_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0876_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0877_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0877_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0878_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0878_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0879_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0879_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0880_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0880_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0881_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0881_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0882_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0882_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0883_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0883_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0884_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0884_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0885_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0885_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0886_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0886_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0887_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0887_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0888_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0888_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0889_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0889_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0890_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0890_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0891_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0891_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0892_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0892_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0893_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0893_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0894_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0894_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0895_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0895_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0896_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0896_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0897_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0897_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0898_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0898_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0899_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0899_Low.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0900_Normal.pt
# Making a binary: /home/elicer/content/data/DIV2K/bin/DIV2K_valid_LQ/0900_Low.pt
# Making model...
# Preparing loss function:
# 1.000 * L1
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: ^C
# Traceback (most recent call last):
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 33, in <module>
#     main()
#   File "/home/elicer/EDSR-PyTorch/src/main.py", line 25, in main
#     t = Trainer(args, loader, _model, _loss, checkpoint)
#   File "/home/elicer/EDSR-PyTorch/src/trainer.py", line 30, in __init__
#     wandb.init(project='RFDN-SuperResolution', name=args.save)
#   File "/home/elicer/.local/lib/python3.10/site-packages/wandb/sdk/wandb_init.py", line 1623, in init
#     wi.maybe_login(init_settings)
#   File "/home/elicer/.local/lib/python3.10/site-packages/wandb/sdk/wandb_init.py", line 208, in maybe_login
#     wandb_login._login(
#   File "/home/elicer/.local/lib/python3.10/site-packages/wandb/sdk/wandb_login.py", line 314, in _login
#     key, key_status = wlogin.prompt_api_key(referrer=referrer)
#   File "/home/elicer/.local/lib/python3.10/site-packages/wandb/sdk/wandb_login.py", line 235, in prompt_api_key
#     key, status = self._prompt_api_key(referrer)
#   File "/home/elicer/.local/lib/python3.10/site-packages/wandb/sdk/wandb_login.py", line 211, in _prompt_api_key
#     key = apikey.prompt_api_key(
#   File "/home/elicer/.local/lib/python3.10/site-packages/wandb/sdk/lib/apikey.py", line 156, in prompt_api_key
#     result = prompt_choices(
#   File "/home/elicer/.local/lib/python3.10/site-packages/wandb/util.py", line 1307, in prompt_choices
#     choice = _prompt_choice(input_timeout=input_timeout, jupyter=jupyter)
#   File "/home/elicer/.local/lib/python3.10/site-packages/wandb/util.py", line 1290, in _prompt_choice
#     choice = input_fn(text)
# KeyboardInterrupt

# %%
# !python main.py \
    --model RFDN \
    --data_train DIV2KCustom \
    --data_test DIV2KCustom \
    --dir_data /home/elicer/content/data \
    --scale 4 \
    --patch_size 96 \
    --batch_size 16 \
    --epochs 10 \
    --lr 1e-4 \
    --save RFDN_x4_custom \
    --ext sep
# Out:
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Preparing loss function:
# 1.000 * L1
# wandb: Currently logged in as: vecum0814 (vecum0814-korea-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.11
# wandb: Run data is saved locally in /home/elicer/EDSR-PyTorch/src/wandb/run-20250525_104938-i09imi1o
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run RFDN_x4_custom
# wandb: ⭐️ View project at https://wandb.ai/vecum0814-korea-university/RFDN-SuperResolution
# wandb: 🚀 View run at https://wandb.ai/vecum0814-korea-university/RFDN-SuperResolution/runs/i09imi1o
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 1]	Learning rate: 1.00e-4
# Epoch 1/10:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 1/10: 100%|███████████████| 100/100 [00:04<00:00, 20.62it/s, Loss=25.1197]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:10<00:00, 18.40it/s]
# [DIV2KCustom x4]	PSNR: 19.668
# Forward: 10.87s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 2]	Learning rate: 1.00e-4
# Epoch 2/10:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 2/10: 100%|███████████████| 100/100 [00:02<00:00, 33.50it/s, Loss=22.3780]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:10<00:00, 19.30it/s]
# [DIV2KCustom x4]	PSNR: 21.248
# Forward: 10.36s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 3]	Learning rate: 1.00e-4
# Epoch 3/10:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 3/10: 100%|███████████████| 100/100 [00:02<00:00, 33.92it/s, Loss=16.1716]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:10<00:00, 19.33it/s]
# [DIV2KCustom x4]	PSNR: 23.224
# Forward: 10.35s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 4]	Learning rate: 1.00e-4
# Epoch 4/10:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 4/10: 100%|███████████████| 100/100 [00:02<00:00, 34.28it/s, Loss=10.6664]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:10<00:00, 19.42it/s]
# [DIV2KCustom x4]	PSNR: 24.090
# Forward: 10.30s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 5]	Learning rate: 1.00e-4
# Epoch 5/10:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 5/10: 100%|████████████████| 100/100 [00:02<00:00, 33.69it/s, Loss=9.7826]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:10<00:00, 19.19it/s]
# [DIV2KCustom x4]	PSNR: 24.607
# Forward: 10.42s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 6]	Learning rate: 1.00e-4
# Epoch 6/10:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 6/10: 100%|████████████████| 100/100 [00:02<00:00, 33.73it/s, Loss=9.9728]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:10<00:00, 19.40it/s]
# [DIV2KCustom x4]	PSNR: 24.926
# Forward: 10.31s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 7]	Learning rate: 1.00e-4
# Epoch 7/10:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 7/10: 100%|████████████████| 100/100 [00:02<00:00, 34.06it/s, Loss=9.0861]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:10<00:00, 19.27it/s]
# [DIV2KCustom x4]	PSNR: 25.234
# Forward: 10.38s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 8]	Learning rate: 1.00e-4
# Epoch 8/10:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 8/10: 100%|████████████████| 100/100 [00:02<00:00, 33.57it/s, Loss=7.9763]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:10<00:00, 19.33it/s]
# [DIV2KCustom x4]	PSNR: 25.440
# Forward: 10.35s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 9]	Learning rate: 1.00e-4
# Epoch 9/10:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 9/10: 100%|████████████████| 100/100 [00:03<00:00, 33.21it/s, Loss=9.8823]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:10<00:00, 19.20it/s]
# [DIV2KCustom x4]	PSNR: 25.592
# Forward: 10.42s
#
# wandb:
# wandb: 🚀 View run RFDN_x4_custom at: https://wandb.ai/vecum0814-korea-university/RFDN-SuperResolution/runs/i09imi1o
# wandb: Find logs at: wandb/run-20250525_104938-i09imi1o/logs

# %%
import wandb
wandb.login()
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/elicer/.netrc
# wandb: Currently logged in as: vecum0814 (vecum0814-korea-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !python main.py \
    --model RFDN \
    --data_train DIV2KCustom \
    --data_test DIV2KCustom \
    --dir_data /home/elicer/content/data \
    --scale 4 \
    --patch_size 96 \
    --batch_size 16 \
    --epochs 20 \
    --lr 1e-4 \
    --save RFDN_x4_custom \
    --ext sep
# Out:
# /home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Preparing loss function:
# 1.000 * L1
# wandb: Currently logged in as: vecum0814 (vecum0814-korea-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ creating run (0.4s)
# wandb: Tracking run with wandb version 0.19.11
# wandb: Run data is saved locally in /home/elicer/EDSR-PyTorch/src/wandb/run-20250530_144235-cqp388jg
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run RFDN_x4_custom
# wandb: ⭐️ View project at https://wandb.ai/vecum0814-korea-university/RFDN-SuperResolution
# wandb: 🚀 View run at https://wandb.ai/vecum0814-korea-university/RFDN-SuperResolution/runs/cqp388jg
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 1]	Learning rate: 1.00e-4
# Epoch 1/20:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 1/20: 100%|███████████████| 100/100 [01:47<00:00,  1.07s/it, Loss=25.1363]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:19<00:00, 10.43it/s]
# [DIV2KCustom x4]	PSNR: 19.655
# Forward: 19.18s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 2]	Learning rate: 1.00e-4
# Epoch 2/20:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 2/20: 100%|███████████████| 100/100 [00:02<00:00, 34.06it/s, Loss=22.0203]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:15<00:00, 13.18it/s]
# [DIV2KCustom x4]	PSNR: 21.848
# Forward: 15.20s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 3]	Learning rate: 1.00e-4
# Epoch 3/20:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 3/20: 100%|███████████████| 100/100 [00:02<00:00, 35.03it/s, Loss=16.2839]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:15<00:00, 13.12it/s]
# [DIV2KCustom x4]	PSNR: 22.450
# Forward: 15.25s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 4]	Learning rate: 1.00e-4
# Epoch 4/20:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 4/20: 100%|███████████████| 100/100 [00:02<00:00, 34.77it/s, Loss=10.8703]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:15<00:00, 12.83it/s]
# [DIV2KCustom x4]	PSNR: 23.490
# Forward: 15.59s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 5]	Learning rate: 1.00e-4
# Epoch 5/20:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 5/20: 100%|████████████████| 100/100 [00:02<00:00, 35.49it/s, Loss=9.9465]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:15<00:00, 13.00it/s]
# [DIV2KCustom x4]	PSNR: 24.382
# Forward: 15.39s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 6]	Learning rate: 1.00e-4
# Epoch 6/20:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 6/20: 100%|███████████████| 100/100 [00:02<00:00, 34.51it/s, Loss=10.0679]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:14<00:00, 14.05it/s]
# [DIV2KCustom x4]	PSNR: 24.609
# Forward: 14.23s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 7]	Learning rate: 1.00e-4
# Epoch 7/20:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 7/20: 100%|████████████████| 100/100 [00:02<00:00, 33.86it/s, Loss=9.1610]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:15<00:00, 13.17it/s]
# [DIV2KCustom x4]	PSNR: 25.082
# Forward: 15.19s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 8]	Learning rate: 1.00e-4
# Epoch 8/20:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 8/20: 100%|████████████████| 100/100 [00:02<00:00, 34.45it/s, Loss=7.8789]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:14<00:00, 13.46it/s]
# [DIV2KCustom x4]	PSNR: 25.321
# Forward: 14.86s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 9]	Learning rate: 1.00e-4
# Epoch 9/20:   0%|                                       | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 9/20: 100%|████████████████| 100/100 [00:02<00:00, 34.42it/s, Loss=9.9179]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:15<00:00, 13.26it/s]
# [DIV2KCustom x4]	PSNR: 25.462
# Forward: 15.09s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 10]	Learning rate: 1.00e-4
# Epoch 10/20:   0%|                                      | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 10/20: 100%|███████████████| 100/100 [00:02<00:00, 33.97it/s, Loss=7.2137]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:15<00:00, 12.85it/s]
# [DIV2KCustom x4]	PSNR: 25.600
# Forward: 15.57s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 11]	Learning rate: 1.00e-4
# Epoch 11/20:   0%|                                      | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 11/20: 100%|███████████████| 100/100 [00:02<00:00, 34.70it/s, Loss=8.0966]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:14<00:00, 13.50it/s]
# [DIV2KCustom x4]	PSNR: 25.655
# Forward: 14.82s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 12]	Learning rate: 1.00e-4
# Epoch 12/20:   0%|                                      | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 12/20: 100%|███████████████| 100/100 [00:02<00:00, 34.48it/s, Loss=8.3282]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:15<00:00, 13.29it/s]
# [DIV2KCustom x4]	PSNR: 25.734
# Forward: 15.05s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 13]	Learning rate: 1.00e-4
# Epoch 13/20:   0%|                                      | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 13/20: 100%|███████████████| 100/100 [00:02<00:00, 34.35it/s, Loss=9.9548]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:15<00:00, 12.96it/s]
# [DIV2KCustom x4]	PSNR: 25.805
# Forward: 15.45s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 14]	Learning rate: 1.00e-4
# Epoch 14/20:   0%|                                      | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 14/20: 100%|██████████████| 100/100 [00:02<00:00, 34.07it/s, Loss=12.5950]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:15<00:00, 12.66it/s]
# [DIV2KCustom x4]	PSNR: 25.927
# Forward: 15.80s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 15]	Learning rate: 1.00e-4
# Epoch 15/20:   0%|                                      | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 15/20: 100%|███████████████| 100/100 [00:02<00:00, 34.04it/s, Loss=8.2151]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:15<00:00, 13.12it/s]
# [DIV2KCustom x4]	PSNR: 25.950
# Forward: 15.24s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 16]	Learning rate: 1.00e-4
# Epoch 16/20:   0%|                                      | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 16/20: 100%|███████████████| 100/100 [00:02<00:00, 33.42it/s, Loss=8.2969]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:15<00:00, 13.32it/s]
# [DIV2KCustom x4]	PSNR: 26.011
# Forward: 15.01s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 17]	Learning rate: 1.00e-4
# Epoch 17/20:   0%|                                      | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 17/20: 100%|██████████████| 100/100 [00:02<00:00, 33.97it/s, Loss=11.0803]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:16<00:00, 12.29it/s]
# [DIV2KCustom x4]	PSNR: 26.004
# Forward: 16.30s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 18]	Learning rate: 1.00e-4
# Epoch 18/20:   0%|                                      | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 18/20: 100%|███████████████| 100/100 [00:02<00:00, 34.36it/s, Loss=6.2436]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:15<00:00, 13.27it/s]
# [DIV2KCustom x4]	PSNR: 26.052
# Forward: 15.08s
#
# /home/elicer/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:437: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 19]	Learning rate: 1.00e-4
# Epoch 19/20:   0%|                                      | 0/100 [00:00<?, ?it/s]/home/elicer/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 19/20: 100%|███████████████| 100/100 [00:02<00:00, 35.14it/s, Loss=7.8322]
#
# Evaluation:
# Test Dataset: DIV2KCustom: 100%|██████████████| 200/200 [00:15<00:00, 13.07it/s]
# [DIV2KCustom x4]	PSNR: 26.082
# Forward: 15.30s
#
# wandb:
# wandb: 🚀 View run RFDN_x4_custom at: https://wandb.ai/vecum0814-korea-university/RFDN-SuperResolution/runs/cqp388jg
# wandb: Find logs at: wandb/run-20250530_144235-cqp388jg/logs
